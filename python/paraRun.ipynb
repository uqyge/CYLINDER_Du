# %%
import os
import shutil
import time

import numpy as np
import sobol_seq

# %% [markdown]
# # 数据前期准备
# 依据sobol序列，准备一组20个实验数据

# %%
t = [25e-6, 50e-6]
R = [0.02, 0.04]
# c = [0, 1]

data = np.vstack([t, R])

size = 20
vec = sobol_seq.i4_sobol_generate(data.shape[0], size)

lb = data[:, 0]
ub = data[:, 1]

out = vec * (ub - lb) + lb
# print(out)

# %%
out
# Out:
# array([[3.750000e-05, 3.000000e-02],
#        [4.375000e-05, 2.500000e-02],
#        [3.125000e-05, 3.500000e-02],
#        [3.437500e-05, 2.750000e-02],
#        [4.687500e-05, 3.750000e-02],
#        [4.062500e-05, 2.250000e-02],
#        [2.812500e-05, 3.250000e-02],
#        [2.968750e-05, 2.625000e-02],
#        [4.218750e-05, 3.625000e-02],
#        [4.843750e-05, 2.125000e-02],
#        [3.593750e-05, 3.125000e-02],
#        [3.281250e-05, 2.375000e-02],
#        [4.531250e-05, 3.375000e-02],
#        [3.906250e-05, 2.875000e-02],
#        [2.656250e-05, 3.875000e-02],
#        [2.734375e-05, 2.937500e-02],
#        [3.984375e-05, 3.937500e-02],
#        [4.609375e-05, 2.437500e-02],
#        [3.359375e-05, 3.437500e-02],
#        [3.671875e-05, 2.187500e-02]])
